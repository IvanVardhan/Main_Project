# %%
import cv2
import os

def resize_image(image, width=196, height=196):
    dim = (width, height)
    resized = cv2.resize(image, dim, interpolation=cv2.INTER_AREA)
    return resized

def apply_otsu_segmentation(image):
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _, segmented = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
    segmented = cv2.bitwise_not(segmented)  
    return segmented

input_dir = "D:\\MAIN PROJECT\\PROJECT_ANOTHER_DATA\\Alzheimer_s Dataset\\train\\ModerateDemented"
output_dir = "D:\\MAIN PROJECT\\PROJECT_ANOTHER_DATA\\Segmented\\train\\mod"

if not os.path.exists(output_dir):
    os.makedirs(output_dir)

for filename in os.listdir(input_dir):
    if filename.endswith(".jpg") or filename.endswith(".png"):
        input_path = os.path.join(input_dir, filename)
        output_path = os.path.join(output_dir, filename)
        image = cv2.imread(input_path)
        resized_image = resize_image(image, width=196, height=196)
        # Apply Otsu segmentation
        segmented_image = apply_otsu_segmentation(resized_image)
        cv2.imwrite(output_path, segmented_image)
        print(f"Processed and saved: {output_path}")
# Out:
# Processed and saved: D:\MAIN PROJECT\PROJECT_ANOTHER_DATA\Segmented\train\mod\moderateDem0.jpg
# Processed and saved: D:\MAIN PROJECT\PROJECT_ANOTHER_DATA\Segmented\train\mod\moderateDem1.jpg
# Processed and saved: D:\MAIN PROJECT\PROJECT_ANOTHER_DATA\Segmented\train\mod\moderateDem10.jpg
# Processed and saved: D:\MAIN PROJECT\PROJECT_ANOTHER_DATA\Segmented\train\mod\moderateDem11.jpg
# Processed and saved: D:\MAIN PROJECT\PROJECT_ANOTHER_DATA\Segmented\train\mod\moderateDem12.jpg
# Processed and saved: D:\MAIN PROJECT\PROJECT_ANOTHER_DATA\Segmented\train\mod\moderateDem13.jpg
# Processed and saved: D:\MAIN PROJECT\PROJECT_ANOTHER_DATA\Segmented\train\mod\moderateDem14.jpg
# Processed and saved: D:\MAIN PROJECT\PROJECT_ANOTHER_DATA\Segmented\train\mod\moderateDem15.jpg
# Processed and saved: D:\MAIN PROJECT\PROJECT_ANOTHER_DATA\Segmented\train\mod\moderateDem16.jpg
# Processed and saved: D:\MAIN PROJECT\PROJECT_ANOTHER_DATA\Segmented\train\mod\moderateDem17.jpg
# ...
